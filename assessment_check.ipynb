# %%
#this script checks missing and present data for participants
#this is currently set up for the AOL study Assessment measures
#
#TO USE:
#download .csv files with labels and extract the zipped file
#put the unzipped file in the data_dir directory
#update the participants you need to check
#save the file to whatever directory works best for you
#
# BP 7/30/20  

#SET UP#

#calling libraries
import pandas as pd
import xlwt
from xlwt import Workbook

#subjects to check. Must be PHIT IDs for assessments. 
subs = ['12345', '132']

#directory where data is stored. Must have double \\ not just a single \
data_dir = 'C:\\Users\\Becca\Dropbox (UFL)\\Lab Studies\\AOL\\data back up checks\\data\\'
#directory where you want to save the check output files. Must have double \\ not just a single \
save_dir = 'C:\\Users\\Becca\Dropbox (UFL)\\Lab Studies\\AOL\\data back up checks\\data\\'

#must make sure file names match the data you want to use. Must specify csv
preassessment_file="AOL - PreAssessment_July 17, 2020_08.16.csv"
assessment_1_file=
assessment_2_file=
assessment_3_file=
assessment_4_file=
assessment_5_file=
assessment_6_file=

#column names where subID is located. this should not change.
preassessment_id_column= "ID"
assessment_1_id_column=
assessment_2_id_column=
assessment_3_id_column=
assessment_4_id_column=
assessment_5_id_column=
assessment_6_id_column=

#file names to save output. Update with date of most recent data (match the datafile)
save_name_present = 'present_files_assessments_8_2_20.xls'
save_name_missing = 'missing_files_assessments_8_2_20.xls'
wb1 = Workbook()
wb2 = Workbook()
# Out:
#   File "<ipython-input-8-02369f51c290>", line 17
#     assessment_1_file=
#                       ^
# SyntaxError: invalid syntax

# %%
#Pre-Assessment 

id_column = preassessment_id_column
filename = preassessment_file

sheet1 = wb1.add_sheet('assessment 1 present')
sheet2 = wb2.add_sheet('assessment 1 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c8bce15f47dc> in <module>
#       1 #Pre-Assessment
#       2
# ----> 3 id_column = preassessment_id_column
#       4 filename = preassessment_file
#       5
#
# NameError: name 'preassessment_id_column' is not defined

# %%
#Assessment 1

id_column = assessment_1_id_column
filename = assessment_1_file

sheet1 = wb1.add_sheet('preassessment present')
sheet2 = wb2.add_sheet('preassessment missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)

# %%
#Assessment 2

id_column = assessment_2_id_column
filename = assessment_2_file

sheet1 = wb1.add_sheet('assessment 2 present')
sheet2 = wb2.add_sheet('assessment 2 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)

# %%
#Assessment 3

id_column = assessment_3_id_column
filename = assessment_3_file

sheet1 = wb1.add_sheet('assessment 3 present')
sheet2 = wb2.add_sheet('assessment 3 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)

# %%
#Assessment 4

id_column = assessment_4_id_column
filename = assessment_4_file

sheet1 = wb1.add_sheet('assessment 4 present')
sheet2 = wb2.add_sheet('assessment 4 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)

# %%
#Assessment 5

id_column = assessment_5_id_column
filename = assessment_5_file

sheet1 = wb1.add_sheet('assessment 5 present')
sheet2 = wb2.add_sheet('assessment 5 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)

# %%
#Assessment 6

id_column = assessment_6_id_column
filename = assessment_6_file

sheet1 = wb1.add_sheet('assessment 6 present')
sheet2 = wb2.add_sheet('assessment 6 missing')
sheet1.write(0,0,'subID')
sheet2.write(0,0,'subID')
place_counter_missing=0
place_counter_complete=0

col_list = [id_column]
df = pd.read_csv(r'' + data_dir + filename,  usecols=col_list)
data_list = df[id_column].tolist()

for x in subs:
    if x in data_list:
        place_counter_complete=place_counter_complete+1
        sheet1.write(place_counter_complete, 0, x)
    if x not in data_list:
        place_counter_missing=place_counter_missing+1
        sheet2.write(place_counter_missing, 0, x)
        
wb1.save(save_dir + save_name_present)
wb2.save(save_dir + save_name_missing)
